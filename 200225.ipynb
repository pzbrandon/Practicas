# %%
import matplotlib.pyplot as pt

x = 0.99
r = 3.41

cod = []
dom = [0.3]

for i in range(1,10000000):
    x = r*x*(1-x)
    cod.append(x)
    dom.append(x)

dom.pop()

pt.plot(dom, cod)

# %% [markdown]
# 3.5 hay cuatro valores entre los cuales brinca
# 3.2
