# %%
import matplotlib.pyplot as plt
import math as mt
import numpy as np

# %%
def f(x):
    return np.sin(x)

# %%
a = 0
b = np.pi
h = 1e-7

N = int((b-a)/h)
N
# Out:
# 31415926

# %%
X = np.arange(a,b,h)

plt.plot(X,f(X))

# %%
I = (f(a)+f(b))*(h/2)

for k in range(1,N):
    I = I + (f(a+(k-1)*h) + f(a+k*h))*(h/2)

I
# Out:
# 1.9999999999997577
